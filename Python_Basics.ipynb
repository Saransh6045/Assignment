# %% [markdown]
# <a href="https://colab.research.google.com/github/Saransh6045/Assignment/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #print

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print("Machine Learning" + " Basics")
# Out:
# Machine Learning Basics

# %%
print(9)
# Out:
# 9

# %%
print(8+3)
# Out:
# 11

# %% [markdown]
# #Basic Data Types
# * int
# * str
# * float

# %%
type(8)
# Out:
# int

# %% [markdown]
# #Constant & Variables

# %% [markdown]
# #input

# %% [markdown]
# #Basic Data Types
# 1. Integer
# 2. Float
# 3. Complex
# 4. Boolean
# 5. String

# %% [markdown]
# Types of objects in Python
# 1. Immutable objects
# 2. Mutable objects
#
# Mutable objects:
#
#
# *   int
# *   float
# *   str
# *   bool
# *   tuple
#
# Immutable objects:
#
#
# *  List
# *   Set
# *  Dictionary

# %% [markdown]
# #Operators in Python
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparison Operators
# 4. Logical Operators
# 5. Identity Operators
# 6. Membership Operators

# %% [markdown]
# #if else statements, if elif, nested if

# %% [markdown]
# #Loops in Python

# %% [markdown]
# #Functions in Python
